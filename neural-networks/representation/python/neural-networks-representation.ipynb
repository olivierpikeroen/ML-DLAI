# %%
import numpy as np 
from scipy.io import loadmat
import sys
from displayData import *
from predict import *

# %%
data=loadmat('digits.mat')
X=data['X']
y=data['y']
m=X.shape[0]

# %% [markdown]
# # Visualize data

# %%
# Randomly select 100 data points to display
rand_indices=np.random.randint(m,size=100)
sel=X[rand_indices,:]
displayData(sel,20,20)

# %% [markdown]
# # Forward propagation

# %%
weights=loadmat('weights.mat')
theta1,theta2=weights['Theta1'],weights['Theta2']

# %%
pred=predict(theta1,theta2,X)
print('Training Set Accuracy: %.2f'%(np.mean(pred[:,np.newaxis]==y)*100)+'%')
# Out:
# Training Set Accuracy: 97.52%

# %%
ri=np.random.randint(m)
Xi=X[ri,:][np.newaxis,:]
displayData(Xi,20,20)
pred=predict(theta1,theta2,Xi)
print('Neural Network Prediction: %d (digit %d)'%(pred,np.mod(pred,10)))
# Out:
# Neural Network Prediction: 4 (digit 4)
